# %% [markdown]
# The idea would be to run simulations with different values of omega for the oscillations. For example, we could consider:
# * (ω₁ = 1, ω₂ = 5) — the current case — as well as
# * (ω₁ = ω₂ = 1),
# * (ω₁ = ω₂ = 5),
# * (ω₁ = 2, ω₂ = 4),
# * (ω₁ = ω₂ = 2),
# * and (ω₁ = ω₂ = 4).
# For the sequences, we could try different parameter combinations, for example:
# * sg_index = 0.15, ω_gauss = 0.1
# * sg_index = 0.15, ω_gauss = 0.5
# * sg_index = 0.1, ω_gauss = 0.1
# * sg_index = 0.1, ω_gauss = 0.5.
#
#
#
# Ideally we would run 50 seeds for each case, although I realize that this would generate a very large amount of data. I’m not sure if you have access to a server to run them, unfortunately I cannot use the one from my group. If you happen to be able to run them, that would be great.
#
# For each simulation, we could compute the Pearson correlation between each neuron and its corresponding target during the test loops (iloop between 11 and 15). We would first average the Pearson correlation across neurons, and then average across the test loops to obtain a single value per network. Finally, we would average across seeds for each set of parameters.
#
# In this way, for each parameter set we would obtain the mean Pearson correlation of the network (averaged across neurons, test loops, and seeds).
# We could then plot this as colormaps where each row corresponds to a parameter set and each column corresponds to a value of p_{QIF}. The color would represent the value of the Pearson correlation coefficient. We could compute this both for the inputs and for the outputs. In that case, we could have a layout with one row and four columns (or alternatively two rows and two columns): oscillations (inputs), oscillations (outputs), sequences (inputs), and sequences (outputs).
#
# I think it might not be necessary to average over loops since we take 50 seeds, we could just use the first test loop (iloop = 11). In this case, we should run the simulations with iloop = 12 instead of nloop = 16, and it might not be necessary to save the inputs, outputs, and other variables for the training loops
